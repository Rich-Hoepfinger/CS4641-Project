# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("zscore_normalised_trackdata.csv")
df = df.iloc[:,4:].drop('id', axis = 1)
df.head()
# Out:
#    popularity  danceability    energy  key  loudness  mode  speechiness  \
# 0    0.019572      0.149355 -0.922750    5 -1.218679     1    -0.599433
# 1   -0.704828     -1.734542 -0.363093    2 -0.735984     1    -0.374961
# 2   -2.063080     -0.334123 -0.750855    8  0.047829     1    -0.376236
# 3    0.291222     -0.200750 -1.146612    8 -0.233399     1    -0.516531
# 4    0.245947     -0.467497 -1.698273   10 -0.458105     0    -0.445108
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.122510          0.222527 -0.412487  1.708318  0.465212     1.520941
# 1      1.679911          1.125874  0.921129 -1.032001  1.426872    -0.513491
# 2      1.977781          2.312157  0.509695 -0.943480 -1.431400    -0.173100
# 3      1.865320          1.729242 -0.810444 -1.147464 -0.073849    -0.583055
# 4      1.509699         -0.481880 -0.327363 -1.132069 -0.213528     1.336316
#
#    time_signature       genre
# 0               4        jazz
# ...

# %%
features = df.iloc[:,:-1]
corrvals = features.corr()
fig, ax = plt.subplots(figsize=(10,8))
# Collinearity Matrix
sn.heatmap(corrvals, annot = True, ax = ax)
# Out:
# <AxesSubplot: >

# %%
features.drop(["energy", "loudness"], axis = 1, inplace = True)

# %%
corrvals = features.corr()
fig, ax = plt.subplots(figsize=(10,8))
# Collinearity Matrix
sn.heatmap(corrvals, annot = True, ax = ax)
# Out:
# <AxesSubplot: >

# %%
df.drop(["energy", "loudness"], axis = 1, inplace = True)
df.to_csv("collinearity_removed.csv", index = False)

# %%
# from sklearn import feature_selection as fs

# fs.RFE()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 from sklearn import feature_selection as fs
# ----> 3 fs.RFE()
#
# TypeError: RFE.__init__() missing 1 required positional argument: 'estimator'
